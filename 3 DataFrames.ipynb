# %% [markdown]
# ## create a dataframe with three of the optional themes

# %%
import pandas as pd
import requests 
import json

# %% [markdown]
# ## Cat DF

# %%
cat_requests = requests.get('https://cat-fact.herokuapp.com/facts')

# %%
print("cat_requests:",cat_requests.status_code)
# Out:
# cat_requests: 200

# %%
results = cat_requests.json()
#results

# %%
pd.set_option("display.max_rows", 0)
#Getting the list of dictionnaries into the dataframe
data = pd.DataFrame(results)
data.head(10)
# Out:
#                                status                       _id  \
# 0  {'verified': True, 'sentCount': 1}  58e008780aac31001185ed05
# 1  {'verified': True, 'sentCount': 1}  58e009390aac31001185ed10
# 2  {'verified': True, 'sentCount': 1}  588e746706ac2b00110e59ff
# 3  {'verified': True, 'sentCount': 1}  58e008ad0aac31001185ed0c
# 4  {'verified': True, 'sentCount': 1}  58e007cc0aac31001185ecf5
#
#                        user  \
# 0  58e007480aac31001185ecef
# 1  58e007480aac31001185ecef
# 2  588e6e8806ac2b00110e59c3
# 3  58e007480aac31001185ecef
# 4  58e007480aac31001185ecef
#
#                                                 text  __v source  \
# 0  Owning a cat can reduce the risk of stroke and...    0   user
# 1  Most cats are lactose intolerant, and milk can...    0   user
# 2  Domestic cats spend about 70 percent of the da...    0   user
# 3  The frequency of a domestic cat's purr is the ...    0   user
# 4  Cats are the most popular pet in the United St...    0   user
#
# ...

# %%
# def flatten_column(data, column_name):
    flattened = pd.DataFrame(dict(data[column_name])).transpose()
    columns = [str(col) for col in flattened.columns]
    flattened.columns = [column_name + '_' + colname for colname in columns]
    data = pd.concat([data, flattened], axis=1)
    data = data.drop(column_name, axis=1)
    return data

data1 = flatten_column(data, 'status')
data1

# %% [markdown]
# ## Public Holidays NL

# %%
#/api/v3/PublicHolidays/{Year}/{CountryCode}

# %%
pholiday_response = requests.get ('https://date.nager.at/api/v3/publicholidays/2023/NL')
print("Public Holiday:", pholiday_response.status_code)
# Out:
# Public Holiday: 200

# %%
results = pholiday_response.json()
#results

# %%
pd.set_option("display.max_rows", 0)
data = pd.DataFrame(results)
data.head(10)
# Out:
#          date           localName            name countryCode  fixed  global  \
# 0  2023-01-01       Nieuwjaarsdag  New Year's Day          NL   True    True
# 1  2023-04-07       Goede Vrijdag     Good Friday          NL  False    True
# 2  2023-04-09      Eerste Paasdag   Easter Sunday          NL  False    True
# 3  2023-04-10      Tweede Paasdag   Easter Monday          NL  False    True
# 4  2023-04-27          Koningsdag      King's Day          NL   True    True
# 5  2023-05-05      Bevrijdingsdag  Liberation Day          NL   True    True
# 6  2023-05-18      Hemelvaartsdag   Ascension Day          NL  False    True
# 7  2023-05-28  Eerste Pinksterdag       Pentecost          NL  False    True
# 8  2023-05-29  Tweede Pinksterdag     Whit Monday          NL  False    True
# 9  2023-12-25     Eerste Kerstdag   Christmas Day          NL   True    True
#
#   counties  launchYear                  types
# 0     None      1967.0               [Public]
# ...

# %% [markdown]
# ## Harry Potter Characters

# %%
hpc = requests.get ('https://hp-api.onrender.com/api/characters')

# %%
print("harry potter characters:", hpc.status_code)
# Out:
# harry potter characters: 200

# %%
results = hpc.json()
#results

# %%
pd.set_option("display.max_rows", 0)
data = pd.DataFrame(results)
data.head(10)
# Out:
#                                      id                name  \
# 0  9e3f7ce4-b9a7-4244-b709-dae5c1f1d4a8        Harry Potter
# 1  4c7e6819-a91a-45b2-a454-f931e4a7cce3    Hermione Granger
# 2  c3b1f9a5-b87b-48bf-b00d-95b093ea6390         Ron Weasley
# 3  af95bd8a-dfae-45bb-bc69-533860d34129        Draco Malfoy
# 4  ca3827f0-375a-4891-aaa5-f5e8a5bad225  Minerva McGonagall
# 5  d5c4daa3-c726-426a-aa98-fb40f3fba816      Cedric Diggory
# 6  8f9aa40b-5d7c-441e-ad32-4564ecda3b70           Cho Chang
# 7  3569d265-bd27-44d8-88e8-82fb0a848374       Severus Snape
# 8  36bfefd0-e0bb-4d11-be98-d1ef6117a77a       Rubeus Hagrid
# 9  3db6dc51-b461-4fa4-a6e4-b1ff352221c5  Neville Longbottom
#
#                                      alternate_names     species  gender  \
# 0  [The Boy Who Lived, The Chosen One, Undesirabl...       human    male
# 1   [Hermy, Know-it-all, Miss Grant, Herm-own-ninny]       human  female
# 2  [Dragomir Despard, Ronald, Ickle Ronniekins, R...       human    male
# ...
